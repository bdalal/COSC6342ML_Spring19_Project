# %%
import pandas as pd

# %%
df = pd.read_pickle('../data/feature_dumps/features.pkl')

# %%
fm = df[df.Gender == 'M'].FMeasure

# %%
ff = df[df.Gender == 'F'].FMeasure

# %%
fm.values.mean()
# Out:
# 113.0023823704586

# %%
ff.values.mean()
# Out:
# 98.40697674418605

# %%
import seaborn as sns

# %%
sns.pairplot(df[['CharLength', 'FMeasure']])
